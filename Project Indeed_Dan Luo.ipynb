# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

# document saving folder
from pathlib import Path
filepath = Path('C:/Users/Public/Documents/crawler.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  

# using chromedriver
PATH = "Downloads/chromedriver.exe"
driver = webdriver.Chrome(PATH)

# initialize scrapying information you desire
jobtitles = []
companies = []
locations = []
descriptions = []

# how many pages you want to scrapy
for i in range(0,110,10):
    
    # get each page weblink
    driver.get('https://www.indeed.com/jobs?q=data%20scientist&l=united%20states&start='+str(i))
    driver.implicitly_wait(5)
    
    # slider_container is each single job slot containing all the information
    jobs = driver.find_elements_by_class_name("slider_container")

    for job in jobs:

        jobtitle = job.find_element_by_class_name('jobTitle').text.replace("new", "").strip()
        jobtitles.append(jobtitle)
        company = job.find_element_by_class_name('companyName').text.replace("new", "").strip()
        companies.append(company)
        location = job.find_element_by_class_name('companyLocation').text.replace("new", "").strip()
        locations.append(location)
        description = job.find_element_by_class_name('job-snippet').text.replace("new", "").strip()
        descriptions.append(description)
        try:
            WebDriverWait(driver, 5).until(EC.visibility_of_element_located((By.CSS_SELECTOR, "button.popover-x-button-close.icl-CloseButton"))).click()
        except:
            pass



df = pd.DataFrame()
df['JobTitle']=jobtitles
df['Company']=companies
df['Location']=locations
df['Description']=descriptions
display(df)

# convert to csv.

df.to_csv(filepath)
# Out:
#                                               JobTitle  \
# 0                             Principal Data Scientist
# 1                 Autonomous Systems Applied Scientist
# 2    Cloud Data Engineer II - Enterprise Analytics ...
# 3                                       Data Scientist
# 4                            Sr Marketing Data Analyst
# ..                                                 ...
# 160                              Junior Data Scientist
# 161                          Data Scientist Specialist
# 162                                     Data scientist
# 163                            Data Scientist (Remote)
# 164                            Data Scientist II - NLP
#
#                                     Company  \
# 0                 Jones Grove IT Recruiting
# 1                              Metron, Inc.
# 2             The Travelers Companies, Inc.
# 3                            Infinity Quest
# 4                 Academy Sports + Outdoors
# ..                                      ...
# 160                                  Noblis
# 161                               Accenture
# 162                           Avila Trading
# 163  Cambridge Technology Enterprises (CTE)
# 164                             Ursus, Inc.
#
#                                               Location  \
# 0                 Hybrid remote in Charlotte, NC 28209
# 1               Reston, VA 20190 \n(Sunset Hills area)
# 2    Hartford, CT 06101 \n(North Meadows area)\n+2 ...
# 3                                               Remote
# 4                                             Katy, TX
# ..                                                 ...
# 160                  Hybrid remote in Reston, VA 20191
# 161                        San Diego, CA\n+5 locations
# 162                                  San Francisco, CA
# 163                                             Remote
# 164       Remote in Menlo Park, CA 94025\n+2 locations
#
#                                            Description
# 0    Be a key contributor to the data science strat...
# 1    You will be part of a team of scientists and s...
# 2    Incorporate core data management competencies ...
# 3    Experience of working on a project end-to-end:...
# 4    Develop intuitive and informative data visuali...
# ..                                                 ...
# 160  Team members will work collaboratively with th...
# 161  Experience collaborating with a team of data s...
# 162  (Ability to write functions, clean and efficie...
# 163  Knowledge of machine learning and deep learnin...
# 164  " Apply knowledge of statistics, machine learn...
#
# [165 rows x 4 columns]
